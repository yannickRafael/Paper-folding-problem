# %%
import matplotlib.pyplot as plt

# %%
def thickness_of_the_paper_folded(thickness, times):
    list = []
    list.append(thickness)
    a = 1
    for i in range(0, times):
        a = 2 * a
        t =  (thickness*a)/1000
        list.append(t)
    return list

# %%
plt.title('Thickness of folded paper')
# Out:
# Text(0.5, 1.0, 'Thickness of folded paper')

# %%
plt.xlabel('number of folds')
# Out:
# Text(0.5, 0, 'number of folds')

# %%
plt.ylabel('Thickness [km]')
# Out:
# Text(0, 0.5, 'Thickness [km]')

# %%
thickness = float(input("Insert the thickness of the paper to be folded: "))
times = int(input("how many times should the paper to be folded?: "))
# Out:
# Insert the thickness of the paper to be folded:  0.00008
# how many times should the paper to be folded?:  43

# %%
list = thickness_of_the_paper_folded(thickness, times)

# %%
plt.plot(list, color='black', linewidth=8, linestyle = 'dashed')#linewidth determines the width and the linestyle, the style
plt.rcParams.update({'font.size': 30})#edits the font size of the value.

# %%
plt.show()

# %%
plt.plot(list, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=5)
